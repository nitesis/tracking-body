# %% [markdown]
# # Imports
#
# - cv2: To capture and manipulate video frames (e.g., from a webcam) and prepare them for processing.
# - mediapipe: To analyze video frames and extract landmarks (e.g., hand or face tracking). This is the machine-learning model used in this project.
# - python-osc: To send processed data (e.g., landmark positions) via the OSC protocol to external software or devices. In this case, it's sending to processing 4.
#
#
# Make sure to have the following installed in the enviroment:
# - `mediapipe`: For landmark detection.
# - `python-osc`: To send data via OSC.
# - `cv2` (OpenCV): To capture and handle video frames.
#
# Hinweis: conda activate ultralytics

# %%
import cv2
import mediapipe as mp
import os
from pythonosc.udp_client import SimpleUDPClient

# %% [markdown]
# # Setting Up OSC and MediaPipe
#
# In this section, we will configure two key components of our project:
#
# 1. **MediaPipe**: A powerful library for real-time perception tasks such as hand tracking, face detection, and pose estimation. It processes video frames to extract meaningful landmarks (e.g., hand positions) which we can use creatively.
#
# 2. **OSC (Open Sound Control)**: A protocol used to send data between different software or hardware. We'll use the Python-OSC library to transmit the data extracted by MediaPipe to other applications, such as Processing or Max/MSP.
#
# The code below initializes these components and prepares them to work together.

# %%
# Setup OSC
OSC_IP = "127.0.0.1"  # Local address
OSC_PORT = 12000      # Port for Processing
client = SimpleUDPClient(OSC_IP, OSC_PORT)

# Setup MediaPipe
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_drawing = mp.solutions.drawing_utils
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734383329.682451 1719778 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2 Pro

# %% [markdown]
# # Listing Available Camera Devices
#
# Before starting the video capture, it's important to know which camera devices are available in the system. This step scans for connected cameras and lists their indices (used to access them in OpenCV) along with their names (if supported).
#
# Use this information to select the correct camera for the application. If no cameras are detected, ensure your device is connected properly or check for driver issues.

# %%
# Gibt den Index der gefundenen Kameras an
def list_camera_devices():
    """Lists available camera devices with their names (if supported)."""
    print("Scanning for available camera devices...")
    available_cameras = []
    for index in range(10):  # Check up to 10 camera indices
        cap = cv2.VideoCapture(index)
        if cap.isOpened():
            # Try to fetch the camera's name, if available
            camera_name = cap.get(cv2.CAP_PROP_DEVICE_NAME) if hasattr(cv2, 'CAP_PROP_DEVICE_NAME') else "Unknown"
            print(f"Index {index}: {camera_name}")
            available_cameras.append((index, camera_name))
            cap.release()
        else:
            print(f"Index {index}: No device detected.")
    if not available_cameras:
        print("No camera devices found.")
    return available_cameras

# Call the function to list devices before starting video capture
cameras = list_camera_devices()
if not cameras:
    print("No cameras available. Exiting.")
    exit()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1734383329.780784 1720334 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1734383329.793733 1720337 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Scanning for available camera devices...
# Index 0: Unknown
# [12/16 22:08:51.562718][info][1719778][Context.cpp:69] Context created with config: default config!
# [12/16 22:08:51.562757][info][1719778][Context.cpp:74] Context work_dir=/Users/vibe/Documents/GitHub/tracking-body
# [12/16 22:08:51.562769][info][1719778][Context.cpp:77] 	- SDK version: 1.9.4
# [12/16 22:08:51.562770][info][1719778][Context.cpp:78] 	- SDK stage version: main
# [12/16 22:08:51.562773][info][1719778][Context.cpp:82] get config EnumerateNetDevice:false
# [12/16 22:08:51.562775][info][1719778][MacPal.cpp:36] createObPal: create MacPal!
# [12/16 22:08:51.563482][info][1719778][MacPal.cpp:104] Create PollingDeviceWatcher!
# [12/16 22:08:51.563492][info][1719778][DeviceManager.cpp:15] Current found device(s): (0)
# [12/16 22:08:51.563495][info][1719778][Pipeline.cpp:15] Try to create pipeline with default device.
# [12/16 22:08:51.563496][warning][1719778][ObException.cpp:5] No device found, fail to create pipeline!
# [12/16 22:08:51.564596][info][1719778][Context.cpp:90] Context destroyed
# Index 1: No device detected.
# [12/16 22:08:51.580217][info][1719778][Context.cpp:69] Context created with config: default config!
# [12/16 22:08:51.580239][info][1719778][Context.cpp:74] Context work_dir=/Users/vibe/Documents/GitHub/tracking-body
# [12/16 22:08:51.580241][info][1719778][Context.cpp:77] 	- SDK version: 1.9.4
# [12/16 22:08:51.580243][info][1719778][Context.cpp:78] 	- SDK stage version: main
# [12/16 22:08:51.580246][info][1719778][Context.cpp:82] get config EnumerateNetDevice:false
# [12/16 22:08:51.580247][info][1719778][MacPal.cpp:36] createObPal: create MacPal!
# [12/16 22:08:51.580448][info][1719778][MacPal.cpp:104] Create PollingDeviceWatcher!
# [12/16 22:08:51.580453][info][1719778][DeviceManager.cpp:15] Current found device(s): (0)
# [12/16 22:08:51.580456][info][1719778][Pipeline.cpp:15] Try to create pipeline with default device.
# [12/16 22:08:51.580458][warning][1719778][ObException.cpp:5] No device found, fail to create pipeline!
# [12/16 22:08:51.580561][info][1719778][Context.cpp:90] Context destroyed
# Index 2: No device detected.
# [12/16 22:08:51.595161][info][1719778][Context.cpp:69] Context created with config: default config!
# [12/16 22:08:51.595185][info][1719778][Context.cpp:74] Context work_dir=/Users/vibe/Documents/GitHub/tracking-body
# [12/16 22:08:51.595186][info][1719778][Context.cpp:77] 	- SDK version: 1.9.4
# [12/16 22:08:51.595187][info][1719778][Context.cpp:78] 	- SDK stage version: main
# [12/16 22:08:51.595190][info][1719778][Context.cpp:82] get config EnumerateNetDevice:false
# [12/16 22:08:51.595191][info][1719778][MacPal.cpp:36] createObPal: create MacPal!
# [12/16 22:08:51.595334][info][1719778][MacPal.cpp:104] Create PollingDeviceWatcher!
# [12/16 22:08:51.595338][info][1719778][DeviceManager.cpp:15] Current found device(s): (0)
# [12/16 22:08:51.595340][info][1719778][Pipeline.cpp:15] Try to create pipeline with default device.
# [12/16 22:08:51.595342][warning][1719778][ObException.cpp:5] No device found, fail to create pipeline!
# [12/16 22:08:51.595455][info][1719778][Context.cpp:90] Context destroyed
# Index 3: No device detected.
# [12/16 22:08:51.610217][info][1719778][Context.cpp:69] Context created with config: default config!
# [12/16 22:08:51.610237][info][1719778][Context.cpp:74] Context work_dir=/Users/vibe/Documents/GitHub/tracking-body
# [12/16 22:08:51.610239][info][1719778][Context.cpp:77] 	- SDK version: 1.9.4
# [12/16 22:08:51.610240][info][1719778][Context.cpp:78] 	- SDK stage version: main
# [12/16 22:08:51.610242][info][1719778][Context.cpp:82] get config EnumerateNetDevice:false
# [12/16 22:08:51.610244][info][1719778][MacPal.cpp:36] createObPal: create MacPal!
# [12/16 22:08:51.610408][info][1719778][MacPal.cpp:104] Create PollingDeviceWatcher!
# [12/16 22:08:51.610416][info][1719778][DeviceManager.cpp:15] Current found device(s): (0)
# [12/16 22:08:51.610418][info][1719778][Pipeline.cpp:15] Try to create pipeline with default device.
# [12/16 22:08:51.610420][warning][1719778][ObException.cpp:5] No device found, fail to create pipeline!
# [12/16 22:08:51.610562][info][1719778][Context.cpp:90] Context destroyed
# Index 4: No device detected.
# [12/16 22:08:51.626261][info][1719778][Context.cpp:69] Context created with config: default config!
# [12/16 22:08:51.626286][info][1719778][Context.cpp:74] Context work_dir=/Users/vibe/Documents/GitHub/tracking-body
# [12/16 22:08:51.626287][info][1719778][Context.cpp:77] 	- SDK version: 1.9.4
# [12/16 22:08:51.626288][info][1719778][Context.cpp:78] 	- SDK stage version: main
# [12/16 22:08:51.626292][info][1719778][Context.cpp:82] get config EnumerateNetDevice:false
# [12/16 22:08:51.626293][info][1719778][MacPal.cpp:36] createObPal: create MacPal!
# [12/16 22:08:51.626479][info][1719778][MacPal.cpp:104] Create PollingDeviceWatcher!
# [12/16 22:08:51.626485][info][1719778][DeviceManager.cpp:15] Current found device(s): (0)
# [12/16 22:08:51.626487][info][1719778][Pipeline.cpp:15] Try to create pipeline with default device.
# [12/16 22:08:51.626489][warning][1719778][ObException.cpp:5] No device found, fail to create pipeline!
# [12/16 22:08:51.626616][info][1719778][Context.cpp:90] Context destroyed
# Index 5: No device detected.
# [12/16 22:08:51.641137][info][1719778][Context.cpp:69] Context created with config: default config!
# [12/16 22:08:51.641173][info][1719778][Context.cpp:74] Context work_dir=/Users/vibe/Documents/GitHub/tracking-body
# [12/16 22:08:51.641176][info][1719778][Context.cpp:77] 	- SDK version: 1.9.4
# [12/16 22:08:51.641177][info][1719778][Context.cpp:78] 	- SDK stage version: main
# [12/16 22:08:51.641182][info][1719778][Context.cpp:82] get config EnumerateNetDevice:false
# [12/16 22:08:51.641183][info][1719778][MacPal.cpp:36] createObPal: create MacPal!
# [12/16 22:08:51.641323][info][1719778][MacPal.cpp:104] Create PollingDeviceWatcher!
# [12/16 22:08:51.641327][info][1719778][DeviceManager.cpp:15] Current found device(s): (0)
# [12/16 22:08:51.641329][info][1719778][Pipeline.cpp:15] Try to create pipeline with default device.
# [12/16 22:08:51.641331][warning][1719778][ObException.cpp:5] No device found, fail to create pipeline!
# [12/16 22:08:51.641431][info][1719778][Context.cpp:90] Context destroyed
# Index 6: No device detected.
# [12/16 22:08:51.655752][info][1719778][Context.cpp:69] Context created with config: default config!
# [12/16 22:08:51.655776][info][1719778][Context.cpp:74] Context work_dir=/Users/vibe/Documents/GitHub/tracking-body
# [12/16 22:08:51.655778][info][1719778][Context.cpp:77] 	- SDK version: 1.9.4
# [12/16 22:08:51.655779][info][1719778][Context.cpp:78] 	- SDK stage version: main
# [12/16 22:08:51.655781][info][1719778][Context.cpp:82] get config EnumerateNetDevice:false
# [12/16 22:08:51.655782][info][1719778][MacPal.cpp:36] createObPal: create MacPal!
# [12/16 22:08:51.655919][info][1719778][MacPal.cpp:104] Create PollingDeviceWatcher!
# [12/16 22:08:51.655924][info][1719778][DeviceManager.cpp:15] Current found device(s): (0)
# [12/16 22:08:51.655926][info][1719778][Pipeline.cpp:15] Try to create pipeline with default device.
# [12/16 22:08:51.655927][warning][1719778][ObException.cpp:5] No device found, fail to create pipeline!
# [12/16 22:08:51.656031][info][1719778][Context.cpp:90] Context destroyed
# Index 7: No device detected.
# [12/16 22:08:51.670295][info][1719778][Context.cpp:69] Context created with config: default config!
# [12/16 22:08:51.670325][info][1719778][Context.cpp:74] Context work_dir=/Users/vibe/Documents/GitHub/tracking-body
# [12/16 22:08:51.670327][info][1719778][Context.cpp:77] 	- SDK version: 1.9.4
# [12/16 22:08:51.670328][info][1719778][Context.cpp:78] 	- SDK stage version: main
# [12/16 22:08:51.670331][info][1719778][Context.cpp:82] get config EnumerateNetDevice:false
# [12/16 22:08:51.670332][info][1719778][MacPal.cpp:36] createObPal: create MacPal!
# [12/16 22:08:51.670477][info][1719778][MacPal.cpp:104] Create PollingDeviceWatcher!
# [12/16 22:08:51.670484][info][1719778][DeviceManager.cpp:15] Current found device(s): (0)
# [12/16 22:08:51.670486][info][1719778][Pipeline.cpp:15] Try to create pipeline with default device.
# [12/16 22:08:51.670488][warning][1719778][ObException.cpp:5] No device found, fail to create pipeline!
# [12/16 22:08:51.670622][info][1719778][Context.cpp:90] Context destroyed
# Index 8: No device detected.
# [12/16 22:08:51.684699][info][1719778][Context.cpp:69] Context created with config: default config!
# [12/16 22:08:51.684724][info][1719778][Context.cpp:74] Context work_dir=/Users/vibe/Documents/GitHub/tracking-body
# [12/16 22:08:51.684727][info][1719778][Context.cpp:77] 	- SDK version: 1.9.4
# [12/16 22:08:51.684728][info][1719778][Context.cpp:78] 	- SDK stage version: main
# [12/16 22:08:51.684731][info][1719778][Context.cpp:82] get config EnumerateNetDevice:false
# [12/16 22:08:51.684732][info][1719778][MacPal.cpp:36] createObPal: create MacPal!
# [12/16 22:08:51.684879][info][1719778][MacPal.cpp:104] Create PollingDeviceWatcher!
# [12/16 22:08:51.684882][info][1719778][DeviceManager.cpp:15] Current found device(s): (0)
# [12/16 22:08:51.684885][info][1719778][Pipeline.cpp:15] Try to create pipeline with default device.
# [12/16 22:08:51.684886][warning][1719778][ObException.cpp:5] No device found, fail to create pipeline!
# [12/16 22:08:51.685019][info][1719778][Context.cpp:90] Context destroyed
# Index 9: No device detected.
# OpenCV: out device of bound (0-0): 1
# OpenCV: camera failed to properly initialize!
# [ WARN:0@5.590] global cap.cpp:323 open VIDEOIO(OBSENSOR): raised unknown C++ exception!
#
#
# OpenCV: out device of bound (0-0): 2
# OpenCV: camera failed to properly initialize!
# [ WARN:0@5.605] global cap.cpp:323 open VIDEOIO(OBSENSOR): raised unknown C++ exception!
#
#
# OpenCV: out device of bound (0-0): 3
# OpenCV: camera failed to properly initialize!
# [ WARN:0@5.620] global cap.cpp:323 open VIDEOIO(OBSENSOR): raised unknown C++ exception!
#
#
# OpenCV: out device of bound (0-0): 4
# OpenCV: camera failed to properly initialize!
# [ WARN:0@5.635] global cap.cpp:323 open VIDEOIO(OBSENSOR): raised unknown C++ exception!
#
#
# OpenCV: out device of bound (0-0): 5
# OpenCV: camera failed to properly initialize!
# [ WARN:0@5.651] global cap.cpp:323 open VIDEOIO(OBSENSOR): raised unknown C++ exception!
#
#
# OpenCV: out device of bound (0-0): 6
# OpenCV: camera failed to properly initialize!
# [ WARN:0@5.666] global cap.cpp:323 open VIDEOIO(OBSENSOR): raised unknown C++ exception!
#
#
# OpenCV: out device of bound (0-0): 7
# OpenCV: camera failed to properly initialize!
# [ WARN:0@5.681] global cap.cpp:323 open VIDEOIO(OBSENSOR): raised unknown C++ exception!
#
#
# OpenCV: out device of bound (0-0): 8
# OpenCV: camera failed to properly initialize!
# [ WARN:0@5.695] global cap.cpp:323 open VIDEOIO(OBSENSOR): raised unknown C++ exception!
#
#
# OpenCV: out device of bound (0-0): 9
# OpenCV: camera failed to properly initialize!
# [ WARN:0@5.710] global cap.cpp:323 open VIDEOIO(OBSENSOR): raised unknown C++ exception!

# %% [markdown]
# # Video Capture and Processing Loop
#
# This part of the code is the heart of the program, where video frames are captured, processed, and visualized in real-time. Here's a breakdown of what each section does:
#
# 1. **Video Capture Initialization**:
#    - `cv2.VideoCapture(2)`: Opens a connection to the webcam (or a specific video source). Replace `2` with `0` or `1` if the camera index needs adjustment for your system.
#
# 2. **Frame Reading**:
#    - `ret, frame = cap.read()`: Reads each frame from the webcam. If `ret` is `False`, it means there are no more frames (e.g., the camera was disconnected).
#
# 3. **Image Conversion**:
#    - `cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)`: Converts the frame from BGR to RGB, as MediaPipe expects RGB images for processing.
#
# 4. **MediaPipe Pose Processing**:
#    - `pose.process(rgb_frame)`: Processes the frame to detect pose landmarks. These landmarks represent keypoints (e.g., joints) of a human pose.
#
# 5. **Visualization (Optional)**:
#    - `mp_drawing.draw_landmarks`: Draws the detected pose landmarks and their connections on the video frame for visualization.
#
# 6. **Send Data via OSC**:
#    - The keypoints from `results.pose_landmarks` are normalized (values between 0 and 1) and prepared as a list. These are sent via OSC to external applications, such as Processing, using the `/pose` OSC address.
#
# 7. **Video Display (Optional)**:
#    - `cv2.imshow('MediaPipe Pose', frame)`: Displays the video frame with landmarks overlaid. This helps verify the system's operation.
#
# 8. **Quit the Loop**:
#    - `cv2.waitKey(1) & 0xFF == ord('q')`: Checks if the "q" key is pressed. If so, it breaks the loop and ends the program.
#
# 9. **Release Resources**:
#    - `cap.release()`: Releases the webcam resource.
#    - `cv2.destroyAllWindows()`: Closes any OpenCV-created windows.
#
# This loop ensures continuous video capture and processing, making it possible to track pose landmarks in real-time and transmit their data seamlessly to other tools.

# %%
# Video capture
# Um andere Kameras z.B. Handycamera zu verbinden, müssen die Geräte mit der selben Apple-ID angemeldet sein
cap = cv2.VideoCapture(0) # Put here the index of the camera device

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # Convert image to RGB (MediaPipe uses RGB)
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = pose.process(rgb_frame)

    # Draw points on the frame (optional, for visualization)
    if results.pose_landmarks:
        mp_drawing.draw_landmarks(frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
        
        # Send keypoints via OSC
        keypoints = []
        for landmark in results.pose_landmarks.landmark:
            keypoints.extend([landmark.x, landmark.y])  # Normalized (0-1)
        client.send_message("/pose", keypoints)

    # Show video with points (optional)
    cv2.imshow('MediaPipe Pose', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# W0000 00:00:1734383332.276881 1720341 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# 2024-12-16 22:08:52.569 python[13209:1719778] +[IMKClient subclass]: chose IMKClient_Modern
# 2024-12-16 22:08:52.569 python[13209:1719778] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 6
#       3 cap = cv2.VideoCapture(0) # Put here the index of the camera device
#       5 while cap.isOpened():
# ----> 6     ret, frame = cap.read()
#       7     if not ret:
#       8         break
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
